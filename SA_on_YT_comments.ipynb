# %% [markdown]
# ### Sentiment Analysis on YouTube Comments
#
# - This notebook is for developing a sentiment analysis model for YouTube Comments

# %%
from google.colab import drive
import os

#mounting google drive
drive.mount('/content/drive')

########################################

#changing the working directory
os.chdir("/content/drive/MyDrive/NLP_Data")

# !pwd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/NLP_Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

import string

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

import warnings
warnings.filterwarnings("ignore")

import requests
import json
import re
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# The functions below handle reading from and writing to a JSON file in the current working directory.

def save_to_json(data, filename):
    """
    Save data to a JSON file.

    Parameters:
    data (dict or list): The data to be saved.
    filename (str): The name of the file to save the data in.
    """
    with open(filename, 'w') as json_file:
        json.dump(data, json_file, indent=4)

def load_from_json(filename):
    """
    Load data from a JSON file.

    Parameters:
    filename (str): The name of the file to load the data from.

    Returns:
    dict or list: The data loaded from the JSON file.
    """
    with open(filename, 'r') as json_file:
        data = json.load(json_file)
    return data

# %%
# we are going to load the YouTube comments json file from the current working directory "filename = 'youtube_comments.json'"
filename = 'youtube_comments.json'
youtube_comments = load_from_json(filename)
# convert the youtube_comments to a pandas dataframe

youtube_comments_df = pd.DataFrame(youtube_comments)

youtube_comments_df.head()
# Out:
#                                         comment_text like_count  reply_count
# 0  A major obstacle to EV adoption that is always...         6K  507 replies
# 1  A major obstacle to EV adoption that is always...         6K  507 replies
# 2  Prices are too high, and dealerships keep addi...       3.9K  216 replies
# 3  The government isn’t fast enough to patch poth...         89    6 replies
# 4  We have the coldest winters in many years here...         34      1 reply

# %%
# Function to convert string values containing suffixes 'K', 'M', or 'B' to integers and extract numeric values.
def convert_to_int(value):
  """
    - If the value is NaN or an empty string, return 0.
    - If the value is a string:
      - Extract numeric digits from the string.
      - Convert the extracted digits to an integer.
      - If the string contains 'K', multiply the number by 1,000.
      - If the string contains 'M', multiply the number by 1,000,000.
      - If the string contains 'B', multiply the number by 1,000,000,000.
    - Return the converted integer value.

  """
  if pd.isna(value) or value == '':
      return 0
  if isinstance(value, str):
      # Extract numbers and convert them
      num = re.findall(r'\d+', value)
      if not num:
          return 0
      num = ''.join(num)
      if 'K' in value:
          return int(float(num) * 1000)
      if 'M' in value:
          return int(float(num) * 1000000)
      if 'B' in value:
          return int(float(num) * 1000000000)
      return int(num)
  return int(value)

# %%
# We are going to do a little bit of cleaning on the dataset

# Fill missing and empty values with 0
youtube_comments_df['like_count'].replace('', 0, inplace=True)
youtube_comments_df['reply_count'].replace('', 0, inplace=True)
youtube_comments_df.fillna({'like_count': 0, 'reply_count': 0}, inplace=True)

# Convert columns to integers
youtube_comments_df['like_count'] = youtube_comments_df['like_count'].apply(convert_to_int)
youtube_comments_df['reply_count'] = youtube_comments_df['reply_count'].apply(convert_to_int)

# %%
# Shuffle the rows of the DataFrame `comments_data` randomly with a fixed seed for reproducibility.
# Reset the index of the DataFrame to be sequential and drop the old index column.
# Display the first few rows of the shuffled DataFrame.
youtube_comments_df = youtube_comments_df.sample(frac=1, random_state=42).reset_index(drop=True)
youtube_comments_df.head()
# Out:
#                                         comment_text  like_count  reply_count
# 0                                     English please           0            0
# 1  I still fucking love this so much. Eat worm sh...           3            0
# 2  ngl i do enjoy the action stuff w smaug even i...           0            0
# 3                                          LeLowGear           0            0
# 4  This guys dish has more forks than his family ...           0            0

# %% [markdown]
# Note: We will be revisiting the text cleaning and preparation of the `YouTube_comments` dataset.
# Given that the dataset may contain comments in different languages, special characters, or non-alphanumeric symbols,
# it is crucial to address these aspects for effective preprocessing.
# #### Below are some strategies we will use to improve the cleaning process:
#
# 1. **Language Detection**:
#     - Identify and handle comments in various languages separately.
#     - Utilize language identification tools like `langdetect` or `TextBlob` to determine the language of each comment.
# 2. **Character Removal**:
#     - Remove or normalize special characters and non-alphanumeric symbols to ensure consistency.
#     - Use regular expressions to filter out unwanted characters and retain only relevant text.
#
# 3. **Unicode Normalization**:
#     - Normalize Unicode characters to handle different encodings and symbols.
#     - Employ libraries like `unicodedata` to standardize text.
#
# 4. **Text Standardization**:
#     - Convert text to a consistent case (e.g., lowercase) to ensure uniformity.
#     - Remove extra whitespace and redundant characters.
#
# 5. **Language-Specific Processing**:
#     - Apply language-specific preprocessing techniques for better accuracy, such as stemming or lemmatization.
#     - Consider translation or transliteration if necessary for multilingual comments.
#
# 6. **Tokenization and Lemmatization**:
#     - Tokenize text into words or phrases and apply lemmatization to reduce words to their base forms.
#
#  Implementing these methods will enhance the quality of our text data, making it more suitable for analysis or model training.

# %%
# Now we get a random sample of 200 comments and do some tests
sample_comments = youtube_comments_df.sample(n=200, random_state=42).reset_index(drop=True)
sample_comments.head()
# Out:
#                                         comment_text  like_count  reply_count
# 0  It might be possible to power EVs using solar,...           0            0
# 1                  Imagine the smell of this factory          29            3
# 2  i went for a history degree, and I still had t...           0            0
# 3   Wow They really made a 2 minute vid into a mess.           0            0
# 4  What if: instead of upgrading the ships protec...           0            0

# %%
sample_comments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   comment_text  200 non-null    object
#  1   like_count    200 non-null    int64
#  2   reply_count   200 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 4.8+ KB

# %%
pip install langdetect
# Out:
# Requirement already satisfied: langdetect in /usr/local/lib/python3.10/dist-packages (1.0.9)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect) (1.16.0)

# %%
# prompt: # Iterate over the 'comment_text' column and if the comment is contain non English characters print it out

from langdetect import detect
print("[")
for comment in sample_comments['comment_text']:
  try:
    language = detect(comment)
    if language != 'en':
      print(f"'{comment}',")
  except:
    pass
print("]")
# Out:
# [
# 'Jajaja I Go There Para Ponerme Mas JovenJajajajajaja',
# 'Giant mochi!!!!!',
# 'HELTER SKELTER',
# 'إن من أعظم الواجبات الدينية الأمر بالمعروف والنهي عن المنكر، قال الله تعالى: [وَلْتَكُنْ مِنْكُمْ أُمَّةٌ يَدْعُونَ إِلَى الْخَيْرِ وَيَأْمُرُونَ بِالْمَعْرُوفِ وَيَنْهَوْنَ عَنِ الْمُنْكَرِ وَأُولَئِكَ هُمُ الْمُفْلِحُونَ].
# روي عن النبي (صلى الله عليه وآله) أنه قال: (كيف بكم إذا فسدت نساؤكم، وفسق شبابكم، ولم تأمروا بالمعروف ولم تنهوا عن المنكر) فقيل له: ويكون ذلك يا رسول الله؟ قال صلى الله عليه وآله: (نعم). فقال: (كيف بكم إذا أمرتم بالمنكر، ونهيتم عن المعروف) فقيل له: يا رسول الله ويكون ذلك؟ فقال: (نعم وشر من ذلك كيف بكم إذا رأيتم المعروف منكراً والمنكر معروفاً؟).
# وقد روي عنهم (عليهم السلام): أن بالأمر بالمعروف تقام الفرائض وتأمن المذاهب، وتحل المكاسب، وتمنع المظالم وتعمر الأرض وينتصف للمظلوم من الظالم، ولا يزال الناس بخير ما أمروا بالمعروف، ونهوا عن المنكر، وتعاونوا على البر فإذا لم يفعلوا ذلك نزعت منهم البركات وسلط بعضهم على بعض، ولم يكن لهم ناصر في الأرض ولا في السماء..',
# 'Awesome!',
# 'Looks beautiful',
# 'Trump jokes age well',
# 'Y te sigo desde asé muchos años por qué eres mi mejor yeotuber',
# 'Allahım bu adamdan daha zengin olmak istiyorum',
# 'no one wants junk. diesel 4 life',
# 'Kliies',
# 'respect',
# 'If you ever meet Tom Hanks it will be awkward',
# 'Project Hypersaw...',
# '34:38“To me-ee.”',
# 'M',
# 'Lol',
# 'বাই আপনিতো আনেক বরো লোক আনেক মানুসেরে আনেক কিছুই দেন আমি সাদারোন মানুস আমাকে কি কিছু দিলে আপনার কিছু কমে জাইবো আমাকে কিছু একটাদেন না বাই আপনারতো আনেক টাকা পইসা আমাকে কিছু একটা দেন না',
# 'Majestuoso!!!',
# 'Ng Vn điểm danh',
# 'zavarions a fire name damn',
# 'СССР, прикольно)',
# 'Lmaoooo',
# '원작 고증 미쳤다 오징어게임 미스터비스트 최고!',
# 'What a joke lol',
# 'Jajaja increíble que contrataron al mismo doblador de las pelis de la roca xdd',
# '中國之所以強大，是因為中國共產黨將十四億中國人的幸福，作為奮鬥的目標🇨🇳🇨🇳感恩中國共產黨',
# 'i love you papua indonesia',
# '#lifetimesupportofficial',
# ]

# %%
# prompt:

# %%
# Iterate over the 'comment_text' column and if the comment is not English print it out

from langdetect import detect

for i, comment in enumerate(sample_comments['comment_text']):
  try:
    language = detect(comment)
    if language != 'en':
      print(f"{i} --- {comment}")
  except:
    pass
# Out:
# 11 --- Jajaja I Go There Para Ponerme Mas JovenJajajajajaja
# 13 --- Giant mochi!!!!!
# 14 --- HELTER SKELTER
# 16 --- إن من أعظم الواجبات الدينية الأمر بالمعروف والنهي عن المنكر، قال الله تعالى: [وَلْتَكُنْ مِنْكُمْ أُمَّةٌ يَدْعُونَ إِلَى الْخَيْرِ وَيَأْمُرُونَ بِالْمَعْرُوفِ وَيَنْهَوْنَ عَنِ الْمُنْكَرِ وَأُولَئِكَ هُمُ الْمُفْلِحُونَ].
# روي عن النبي (صلى الله عليه وآله) أنه قال: (كيف بكم إذا فسدت نساؤكم، وفسق شبابكم، ولم تأمروا بالمعروف ولم تنهوا عن المنكر) فقيل له: ويكون ذلك يا رسول الله؟ قال صلى الله عليه وآله: (نعم). فقال: (كيف بكم إذا أمرتم بالمنكر، ونهيتم عن المعروف) فقيل له: يا رسول الله ويكون ذلك؟ فقال: (نعم وشر من ذلك كيف بكم إذا رأيتم المعروف منكراً والمنكر معروفاً؟).
# وقد روي عنهم (عليهم السلام): أن بالأمر بالمعروف تقام الفرائض وتأمن المذاهب، وتحل المكاسب، وتمنع المظالم وتعمر الأرض وينتصف للمظلوم من الظالم، ولا يزال الناس بخير ما أمروا بالمعروف، ونهوا عن المنكر، وتعاونوا على البر فإذا لم يفعلوا ذلك نزعت منهم البركات وسلط بعضهم على بعض، ولم يكن لهم ناصر في الأرض ولا في السماء..
# 26 --- Awesome!
# 40 --- Looks beautiful
# 44 --- Y te sigo desde asé muchos años por qué eres mi mejor yeotuber
# 55 --- Allahım bu adamdan daha zengin olmak istiyorum
# 61 --- no one wants junk. diesel 4 life
# 73 --- Kliies
# 82 --- respect
# 83 --- If you ever meet Tom Hanks it will be awkward
# 92 --- Project Hypersaw...
# 109 --- 34:38“To me-ee.”
# 115 --- M
# 117 --- Lol
# 118 --- বাই আপনিতো আনেক বরো লোক আনেক মানুসেরে আনেক কিছুই দেন আমি সাদারোন মানুস আমাকে কি কিছু দিলে আপনার কিছু কমে জাইবো আমাকে কিছু একটাদেন না বাই আপনারতো আনেক টাকা পইসা আমাকে কিছু একটা দেন না
# 127 --- Boring
# 133 --- Majestuoso!!!
# 145 --- Ng Vn điểm danh
# 155 --- zavarions a fire name damn
# 159 --- СССР, прикольно)
# 177 --- Lmaoooo
# 178 --- 원작 고증 미쳤다 오징어게임 미스터비스트 최고!
# 180 --- What a joke lol
# 182 --- Jajaja increíble que contrataron al mismo doblador de las pelis de la roca xdd
# 188 --- 中國之所以強大，是因為中國共產黨將十四億中國人的幸福，作為奮鬥的目標🇨🇳🇨🇳感恩中國共產黨
# 194 --- i love you papua indonesia
# 196 --- #lifetimesupportofficial

# %%
# Iterate over the 'comment_text' column and if the comment is contain non English characters print it out and drop the rows. from the dataframe
indices_to_drop = []
for index, comment in enumerate(sample_comments['comment_text']):
  try:
    language = detect(comment)
    if language != 'en':
      print(f"Dropping comment: '{comment}'")
      indices_to_drop.append(index)
  except:
    pass

# Drop the rows with non-English comments
sample_comments = sample_comments.drop(indices_to_drop).reset_index(drop=True)
# Out:
# Dropping comment: 'Jajaja I Go There Para Ponerme Mas JovenJajajajajaja'
# Dropping comment: 'Giant mochi!!!!!'
# Dropping comment: 'HELTER SKELTER'
# Dropping comment: 'إن من أعظم الواجبات الدينية الأمر بالمعروف والنهي عن المنكر، قال الله تعالى: [وَلْتَكُنْ مِنْكُمْ أُمَّةٌ يَدْعُونَ إِلَى الْخَيْرِ وَيَأْمُرُونَ بِالْمَعْرُوفِ وَيَنْهَوْنَ عَنِ الْمُنْكَرِ وَأُولَئِكَ هُمُ الْمُفْلِحُونَ].
# روي عن النبي (صلى الله عليه وآله) أنه قال: (كيف بكم إذا فسدت نساؤكم، وفسق شبابكم، ولم تأمروا بالمعروف ولم تنهوا عن المنكر) فقيل له: ويكون ذلك يا رسول الله؟ قال صلى الله عليه وآله: (نعم). فقال: (كيف بكم إذا أمرتم بالمنكر، ونهيتم عن المعروف) فقيل له: يا رسول الله ويكون ذلك؟ فقال: (نعم وشر من ذلك كيف بكم إذا رأيتم المعروف منكراً والمنكر معروفاً؟).
# وقد روي عنهم (عليهم السلام): أن بالأمر بالمعروف تقام الفرائض وتأمن المذاهب، وتحل المكاسب، وتمنع المظالم وتعمر الأرض وينتصف للمظلوم من الظالم، ولا يزال الناس بخير ما أمروا بالمعروف، ونهوا عن المنكر، وتعاونوا على البر فإذا لم يفعلوا ذلك نزعت منهم البركات وسلط بعضهم على بعض، ولم يكن لهم ناصر في الأرض ولا في السماء..'
# Dropping comment: 'Awesome!'
# Dropping comment: 'Looks beautiful'
# Dropping comment: 'Trump jokes age well'
# Dropping comment: 'Y te sigo desde asé muchos años por qué eres mi mejor yeotuber'
# Dropping comment: 'Allahım bu adamdan daha zengin olmak istiyorum'
# Dropping comment: 'no one wants junk. diesel 4 life'
# Dropping comment: 'Kliies'
# Dropping comment: 'respect'
# Dropping comment: 'If you ever meet Tom Hanks it will be awkward'
# Dropping comment: 'Project Hypersaw...'
# Dropping comment: '34:38“To me-ee.”'
# Dropping comment: 'M'
# Dropping comment: 'Lol'
# Dropping comment: 'বাই আপনিতো আনেক বরো লোক আনেক মানুসেরে আনেক কিছুই দেন আমি সাদারোন মানুস আমাকে কি কিছু দিলে আপনার কিছু কমে জাইবো আমাকে কিছু একটাদেন না বাই আপনারতো আনেক টাকা পইসা আমাকে কিছু একটা দেন না'
# Dropping comment: 'Boring'
# Dropping comment: 'Majestuoso!!!'
# Dropping comment: 'Ng Vn điểm danh'
# Dropping comment: 'zavarions a fire name damn'
# Dropping comment: 'СССР, прикольно)'
# Dropping comment: 'Lmaoooo'
# Dropping comment: '원작 고증 미쳤다 오징어게임 미스터비스트 최고!'
# Dropping comment: 'What a joke lol'
# Dropping comment: 'Jajaja increíble que contrataron al mismo doblador de las pelis de la roca xdd'
# Dropping comment: '中國之所以強大，是因為中國共產黨將十四億中國人的幸福，作為奮鬥的目標🇨🇳🇨🇳感恩中國共產黨'
# Dropping comment: 'i love you papua indonesia'
# Dropping comment: '#lifetimesupportofficial'

# %%
# Iterate over the 'comment_text' column and print each comment
for i, comment in enumerate(sample_comments['comment_text']):
  print(f"{i}: ->  {comment}, \n")
# Out:
# 0: ->  It might be possible to power EVs using solar, wind,  and natural power.,
#
# 1: ->  Imagine the smell of this factory,
#
# 2: ->  i went for a history degree, and I still had to take psych 101,
#
# 3: ->  Wow They really made a 2 minute vid into a mess.,
#
# 4: ->  What if: instead of upgrading the ships protection torwards radiation, we increase human resistence torwards radiation, we probably need that anyway if we want to life on other planets. I don't know if It's possible but I think there are some living creatures that are resistent torwards it if we figure out why we might be able to apply it to humans.,
#
# 5: ->  Those mirrors look obnoxiously bad. It's like the bronco is trying to be a moose like ram trucks but a Dumbo the elephant version,
#
# 6: ->  Great video. Btw It would be cool if you added motion effects to the “skull playing chess/pong, drinking tea” picture. Like the clouds in the sky moving, steam from the tea moving, the pong game etc.,
#
# 7: ->  Damn Colby why you hating on my man's nowadays:(,
#
# 8: ->  We just gonna ignore Dan's Hamilton shirt? M'Kay...,
#
# 9: ->  What gets me is if the whole universe was a grain of sand what is the place around the grain of sand,
#
# 10: ->  "I have to believe this, I am British"
# Yeah as a German... I absolutly agree ^^*,
#
# 11: ->  Jajaja I Go There Para Ponerme Mas JovenJajajajajaja,
#
# 12: ->  two handcuffs is diabolical,
#
# 13: ->  Giant mochi!!!!!,
#
# 14: ->  HELTER SKELTER,
#
# 15: ->  Wait till it hits the gut! You'll be able to point where it is at any time. Be sure to have something to hold on to when it's time to come out. ;),
#
# 16: ->  إن من أعظم الواجبات الدينية الأمر بالمعروف والنهي عن المنكر، قال الله تعالى: [وَلْتَكُنْ مِنْكُمْ أُمَّةٌ يَدْعُونَ إِلَى الْخَيْرِ وَيَأْمُرُونَ بِالْمَعْرُوفِ وَيَنْهَوْنَ عَنِ الْمُنْكَرِ وَأُولَئِكَ هُمُ الْمُفْلِحُونَ].
# روي عن النبي (صلى الله عليه وآله) أنه قال: (كيف بكم إذا فسدت نساؤكم، وفسق شبابكم، ولم تأمروا بالمعروف ولم تنهوا عن المنكر) فقيل له: ويكون ذلك يا رسول الله؟ قال صلى الله عليه وآله: (نعم). فقال: (كيف بكم إذا أمرتم بالمنكر، ونهيتم عن المعروف) فقيل له: يا رسول الله ويكون ذلك؟ فقال: (نعم وشر من ذلك كيف بكم إذا رأيتم المعروف منكراً والمنكر معروفاً؟).
# وقد روي عنهم (عليهم السلام): أن بالأمر بالمعروف تقام الفرائض وتأمن المذاهب، وتحل المكاسب، وتمنع المظالم وتعمر الأرض وينتصف للمظلوم من الظالم، ولا يزال الناس بخير ما أمروا بالمعروف، ونهوا عن المنكر، وتعاونوا على البر فإذا لم يفعلوا ذلك نزعت منهم البركات وسلط بعضهم على بعض، ولم يكن لهم ناصر في الأرض ولا في السماء..,
#
# 17: ->  Like can you just do this and skip a cop? To become a USA marine or do you gotta be a cop first,
#
# 18: ->  I love this, the podcast with a live audience is perfect,
#
# 19: ->  I have literally had a gun shop I was purchasing a gun from treat me like they didn't think I was going to pass a background check. This happens. And the unwillingness to be helpful to me. I've experienced this at mostly suburban gun shops/ranges. It actually does happen.,
#
# 20: ->  No one worrying about that shotgun lmfao?,
#
# 21: ->  10:06I'm going to play a game from now on where if I hear anyone bring up false flag racism to attempt a joke, I'm going to drink. This goes for any video I see that brings up false flag racism.,
#
# 22: ->  I’m autistic and this interview is what I go through on a daily basis. He probably isn’t actually autistic but the acting is perfectly spot on.,
#
# 23: ->  New York has a marathon?! Oh wow guys that’s so great- so you’re learning how to run a marathon from competent organizers in Boston who conduct actual marathons?  - great!,
#
# 24: ->  That woman should really keep her thoughts for her gossip group.,
#
# 25: ->  “Slavery is wrong” is never something I thought would’ve had to be said with sincerity to the writer of Harry Potter as a kid,
#
# 26: ->  Awesome!,
#
# 27: ->  I'm excited about Warp Drive! Yes, Warp Drive like they have on Star Trek. Physicist are saying now it is mathematically possible for this to work.,
#
# 28: ->  Wow Doug! This is the dream, reviewing the McLaren F1. This is the peak!,
#
# 29: ->  You can’t say Dumbo Heights without saying SoDaSoPa,
#
# 30: ->  this chick is a chef in new york amd she doesnt know what sodium carbonate is and how to make it,
#
# 31: ->  Jump-scare at the start. You've been warned.,
#
# 32: ->  Aegon the Conqueror wasn’t even the last Targaryen to bring a dragon north. King Jaeharys and Queen Alysanne brought both of their dragons north some 200 years ago and then during the Dance of Dragons Prince Jacerys (spelling?) brought his dragon north. It doesn’t matter since no one died on any of these occasions either but Tyrion would absolutely know this as bookish of a nerd as he is.,
#
# 33: ->  im all for, but if the devil was searching for a place of pure gluttony ill know where to point him too,
#
# 34: ->  Excellent tutorial that explains in good detail!!! Thx for sharing your expertise.,
#
# 35: ->  You are loved angie!!,
#
# 36: ->  I remember in early 2020 I was about to go home from the Philippines, then Taal Volcano had an eruption. 50km away in Manila we could feel the ash coming down on us. This also cancelled my flight. This reminded me of the event I had watched on Air Crash Investigation a long time ago. Lucky for me and my girlfriend, we got to spend a few more hours together before I had to go home.
# Taal Volcano hadn't had an eruption in 40 years, and it happened while I was there. I have never experienced a volcano this close before. While it was a unique experience, it was worse for those living near the volcano and had to flee while their homes got destroyed.,
#
# 37: ->  Men don't get gender exclusive scholarships either, and we are outnumbered in colleges.,
#
# 38: ->  great recipe, but recommend half the salt, despite loving salt. It is twice the amount in classic chocolate chip recipe and can really treasure it in aftertaste.,
#
# 39: ->  wth is this!  what happened to muh muscle car,
#
# 40: ->  Looks beautiful,
#
# 41: ->  Trump jokes age well,
#
# 42: ->  How much i would pay to 1v1 Hasan once… He would never mention ER again lel,
#
# 43: ->  I don’t condone r*pe but, cmon now..how you gonna be in a relationship, decide to work for man in his personal home, be up in his room, naked and laying next to him in bed (while apparently having a partner) and then cry and complain about said man sticking his shtick in you? Something is not adding up. I can’t feel any sort of remorse for someone who intentionally place themselves in such situations. Smh,
#
# 44: ->  Y te sigo desde asé muchos años por qué eres mi mejor yeotuber,
#
# 45: ->  When they got the bugs, it started giving me major Lion King vibes,
#
# 46: ->  if i was one of those officers:
# "oh wow a ceiling!!"
# "wow the weathers nice today!",
#
# 47: ->  Bro I'm glad I'm im a runnerI'm gonna leave it to the heroes,
#
# 48: ->  when can we buy it ?,
#
# 49: ->  Kinda glad to see professional air hockey looks exactly the same as drunk air hockey with the boys,
#
# 50: ->  The only thing is that the original skittles are vegan. So by adding the butter and using gelatine, she made them non vegan.,
#
# 51: ->  this is what's wrong with the world people think its fine to kill fish and package them up like its food..,
#
# 52: ->  How about that terrible company hires enough employees to work all of the registers. They can definitely afford it but they are to greedy.  Best way to fight back is shopping anywhere else,
#
# 53: ->  The whole world needs to smoke weed and chill the fuck out,
#
# 54: ->  I am in favour,
#
# 55: ->  Allahım bu adamdan daha zengin olmak istiyorum,
#
# 56: ->  “its too expensive for me to touch it”
# “ALREADY TOUCHED IT”,
#
# 57: ->  Omg the beep is SO frustrating!
#
# Why don't you just stop being so puritan!,
#
# 58: ->  In 100 years
# Quantum gravity and string theory Will be a stepping stone,
#
# 59: ->  For all of you Irish folk who tried Jack Daniels, I’m sorry you had to actually drink that shite. People in the Lynchburg, TN area sell that to tourists and drink Dickel.,
#
# 60: ->  The impartial windshield nationally flower because pheasant finallly mug from a fast knight. unhealthy, nasty gray,
#
# 61: ->  no one wants junk. diesel 4 life,
#
# 62: ->  Candice is a national treasure,  protect her at all cost,
#
# 63: ->  Scarlett: "don't lie to them they're never coming back"MeLAUGHS AND CRIES AT THE SAME TIME,
#
# 64: ->  she’s such a strong woman️,
#
# 65: ->  "Yeah, it's normal".,
#
# 66: ->  He later tracked the bear down and found no blood? Why would he track it down, after getting almost killed,
#
# 67: ->  i actually did some work there for a short time, i installed a bunch of air lines out of 3/4 inch steel pipe. it took around a week to get clearance just to go inside, its really a fascinating facility!,
#
# 68: ->  every single time this comes up on my recommendations I'm just so mad that police officers are allowed to do this with little to no drawbacks or punishments for their actions.,
#
# 69: ->  The main thing about cooking with C I is to get it up to desired temp before placing food in it. Although I suspect this to be the secret to cooking with most pans, it's definitely the best way I've found with C I. And most times I hardly need any coating unless frying something like chicken or such that I want with a crispy crust all around.,
#
# 70: ->  What is a half uncle/cousin???,
#
# 71: ->  I have an leaf and have no interest in going back to petrol or as you say in the  states gas.  Great video for those that are looking to change over to an EV.   I tell everyone i can that this is the way to go.  If possible I will give them a ride and if there insurance covers my car let them get behind the wheel.   Its the only way.,
#
# 72: ->  I'm reading these comments and I just lost 10% of my intelligence.,
#
# 73: ->  Kliies,
#
# 74: ->  You could just make yourself a drink and put some of it in your truck but nooo lol,
#
# 75: ->  Just knowing my dad is from here, seeing how he fled to America to give me and my family a better chance at life and success, I'm grateful for what my dad does for us to be safe and well,
#
# 76: ->  Actually the little girl damn cute and beautiful and all the children's so beautiful in this prank video. God bless you all.,
#
# 77: ->  Please people listen to what they say that they have no proof , but it must have happened.
# Don't you see the NONCENCE people..,
#
# 78: ->  I will never die for my country
# But if it's for our very precious homosexuals
# I would die for them without any form of hesitation,
#
# 79: ->  How are we finding out that Brad is pregnant through some text in the middle of a skittles video!  CONGRATS BRAD,
#
# 80: ->  Rigid routine? What is the rigid routine?autism intensifies,
#
# 81: ->  He made the fadeaway jumper look cooler and lethal,
#
# 82: ->  respect,
#
# 83: ->  If you ever meet Tom Hanks it will be awkward,
#
# 84: ->  Wasted time of life. It‘s good for nothing. These nobodies should better enroll at university.,
#
# 85: ->  Three guys involved in self promotion and rightly questioned by credible academic scientists.
#
# Joe has been taken in by the half truth told by these guys.️️️️,
#
# 86: ->  I use cast iron and it takes a lot less effort than in this demo. The seasoning builds with use, I can leave mine with water in it to soak for hours and it doesn't rust on the inside, once cleaned I just let it dry at room temperature on the cooker top and only  put more oil in when about to reuse it.  However, for the first several times after re-seasoning it you probably want to follow the steps in the video and not leave it in soak until the seasoning is really well established.,
#
# 87: ->  I miss them together,
#
# 88: ->  59k bs I haven't seen a new car for 60k in my area,
#
# 89: ->  I would never knock 'Sully' and his amazing feat of ditching and saving all souls on board, but the actions of Captain Moody and his crew on this flight are, for me personally, some of the best work ever done. In fact only the story about how Tim Lancaster (Another BA pilot) got sucked halfway out of the windshield and survived is anywhere near as incredible as this story about Mr Moody and his crew. Frist time watching your channel Mentour Pilot but now a subscriber. And the extra aside from Mr Moody himself about the old BOAC captain and his '4 engines out' time on a lancaster rounds up this excellent video brilliantly.,
#
# 90: ->  He laughed at his jokebut Ben isn't who I'd ask for jokes,
#
# 91: ->  Unsubscribed - why? Due to the BS click bait headline,
#
# 92: ->  Project Hypersaw...,
#
# 93: ->  When using baking soda on steak, you only leave the baking soda on for 15- 20 minutes at most. Then rinse it off well. This prevents the "weird" taste he is referring to.,
#
# 94: ->  He was too smart and elite for me and I was too wild and free for him supposedly.,
#
# 95: ->  Son of a "Jimmy Kimmel". That's though
# Hahahaha,
#
# 96: ->  The beardy man: Ooh thats like petrol
# The lovely lady : no, its lovely,
#
# 97: ->  Those are some weak curses.,
#
# 98: ->  just finished it, enjoyed every single second. Jimmy you’re a legend.,
#
# 99: ->  Allen’s ad-libbingright on the set of The Californians on SNL,
#
# 100: ->  Why did he even provoked the poor animal?,
#
# 101: ->  I'm for years in love with the beautiful girl on5:00,
#
# 102: ->  Absolutely heartbreaking. Getting the package to the house on time was more important than his well-being.,
#
# 103: ->  Neil DeGrasse Tyson
#
#  is like the guy who didn't revise for the english exam
# But instead used a book of cliff notes to bluff his way through a conversation with his teacher because he couldn't be bothered to read the book
#
# I can sense he would not last long with a real expert challenging his arguments,
#
# 104: ->  Great Captain !!!,
#
# 105: ->  12:45Blowtorched egg!,
#
# 106: ->  "Sometimes people sick not from the body nor mind, its from their heart",
#
# 107: ->  The Toyota crown is sold outside of Japan?,
#
# 108: ->  Cast iron = perfectly seared steak. That's probably the only reason I own and take care of mine haha.,
#
# 109: ->  34:38“To me-ee.”,
#
# 110: ->  As soon as Andy got his feet onto the couch cushion, I knew this was gonna be a treat!,
#
# 111: ->  can someone please make a consumer electric car. I don't care if it has 120 miles range.,
#
# 112: ->  This should be called:
# "watch time and time again how a man eats potato skins while ignoring the actual potato.",
#
# 113: ->  Hypersonic Rocket,
#
# 114: ->  Been listening to comedy podcasts for over 10yrs and this has gotta be in the TOP 3 I've ever witnessed.
#
# Had to comment just to do my part in helping boost the algorithm cause this gem's views need to go TO DA MOOOON!!!,
#
# 115: ->  M,
#
# 116: ->  Sam was lying like hell!!! He was not ready,
#
# 117: ->  Lol,
#
# 118: ->  বাই আপনিতো আনেক বরো লোক আনেক মানুসেরে আনেক কিছুই দেন আমি সাদারোন মানুস আমাকে কি কিছু দিলে আপনার কিছু কমে জাইবো আমাকে কিছু একটাদেন না বাই আপনারতো আনেক টাকা পইসা আমাকে কিছু একটা দেন না,
#
# 119: ->  please please, lemme be alive to see Gurren pleasseee..,
#
# 120: ->  So a cheeseburger w processed American cheese...damn..
# Who knew!!,
#
# 121: ->  Really? You want to compete with God? Dream on.,
#
# 122: ->  One thing on the list I would add that I can't stop thinking about:
#
# The head of the Inferni in this move claims that "The Inferni killed the Illuminati"
#
# We gotta dig into this,
#
# 123: ->  Booo he's clearly serious.,
#
# 124: ->  i wish i watched endgame on cinema. now i regret it,
#
# 125: ->  What's the original name all the fastest plane,
#
# 126: ->  36:57heart breaking,
#
# 127: ->  Boring,
#
# 128: ->  Are thise ropes holding the hole mech or are they just in case it trips over,
#
# 129: ->  There's about 4: 1:male 2 female in between (which doesn't happen often) and man-made,
#
# 130: ->  Try Hartshorn salt (ammonium carbonate).,
#
# 131: ->  It's an illusion.  Watch the back foot,
#
# 132: ->  Wow️White or Black doesn’t matter!!!
# Good you all found each other and God bless and keep your whole family,
#
# 133: ->  Majestuoso!!!,
#
# 134: ->  Preach it Candace, keep speaking out against this cultural war,
#
# 135: ->  My Universal Observer sees the absolute sequence of all events everywhere, all the time. Anyone who disagrees with this observer is simply wrong.,
#
# 136: ->  My heart goes out to Ukraine.. I've lived there , studied there ..May Lord save the humanity !,
#
# 137: ->  Middle class aren’t buying $50,000 vehicles.,
#
# 138: ->  "Have you ever had Absinthe?"
#
# "No, because I have sense."tips fedora,
#
# 139: ->  I'm sure I've seen that Elephant on Dumbo.,
#
# 140: ->  Jumbalaya is the same dish as "arroz de puta" in brazil.,
#
# 141: ->  This is my go to for drinks to try,
#
# 142: ->  One time when I opened a brand new plater of Ferraro Roche there were maggots in them,
#
# 143: ->  This is beautiful,
#
# 144: ->  American drivers demand comfort, chinese on the other hand more into cheap stuff...you see the different on the look of the cars.,
#
# 145: ->  Ng Vn điểm danh,
#
# 146: ->  How to impress a drill instructor:
# Dont,
#
# 147: ->  Free on a Signature Bond?  what an absolute joke,
#
# 148: ->  Like buying sand in the desert ?,
#
# 149: ->  When the spaceship is smaller than the alien itself!,
#
# 150: ->  ,
#
# 151: ->  Please stick it out til at least 2029, you guys can do it, all of the USA and more are pulling for you.,
#
# 152: ->  Just a reminder that 1 cargo shipping vessel produces the same amount of pollution as 50 million gas powered vehicles in one year.,
#
# 153: ->  "IT'S CHRIS HANSEN" IS THE ONLY FUNNY THING GURGLE HAS EVER SAID,
#
# 154: ->  Her poor brother, oh my goodness. He was so calm and respectful.,
#
# 155: ->  zavarions a fire name damn,
#
# 156: ->  Wow, he's just throwing us the book of logical fallacies,
#
# 157: ->  ,
#
# 158: ->  What about the restrooms???,
#
# 159: ->  СССР, прикольно),
#
# 160: ->  feauters:5 and quality:7 are you kidding me dawg?,
#
# 161: ->  "I just knew him as dad" My heart exploded,
#
# 162: ->  12:55the china comparisons are always out of context,
#
# 163: ->  Teslas and EVs are everywhere in California, and California is the biggest car market in America. Most manufactures worldwide design their cars for sale to  the California market.,
#
# 164: ->  Elon:*Breathes*Audience:,
#
# 165: ->  Shaun You're a Hater. Everything Steven says is true,
#
# 166: ->  I don't know why I'm watching this I don't even have a car,
#
# 167: ->  And it’s still not the worst thing Cosby has done to a woman.,
#
# 168: ->  i feel the pain went George calling for his mama, mamaand that police he such a cruel Guy
#
#
#
#
#
# RIP George Floyd,
#
# 169: ->  Well, on a 45mph or less road, it'll be safer than riding a bicycle.,
#
# 170: ->  I know this is a joke but they are absolutely right.,
#
# 171: ->  Ben Shapiro vibes. Does this prove Ben is infact autistic,
#
# 172: ->  I keep mowing on this crazy idea that What are the odds of me being here now. They are very small. Yet I am here now. Suggesting in some fashion i am always here.,
#
# 173: ->  More fantasty than a Tolkien book... why is this a science channel?,
#
# 174: ->  Yeah such a negative report, your economy is stuffed and you have blocked all quality Chinese EV into your country. Give me an EV over ICE any day of the week. Big oil must of funded this report. Keep driving your stadium trucks and building more roads and watch your countries wealth diminish.,
#
# 175: ->  Make vegan version of convenience foods to figure out what we are doing wrong and how to make foods different/better!,
#
# 176: ->  One of the best ones yet,
#
# 177: ->  Lmaoooo,
#
# 178: ->  원작 고증 미쳤다 오징어게임 미스터비스트 최고!,
#
# 179: ->  I am the emu in those liberty mutual adds
# And you took someones child,
#
# 180: ->  What a joke lol,
#
# 181: ->  Hello Douglas, I can tell you and other white people are angry with all this woke situation and I don't blame you. I'm angry with this as well, as many of other races descendants are.
#
# Be very careful in your response brother. No one would be benefited by white people fighting other races as much as other races would not really benefit from the war against the West.
#
# Never forget Douglas, that is not black people, latinos, Asians, middle eastern, or any other ethnicity totality of population who are welding a war against the West. It is an specific group of people
# , "the woke fanatics" (which by the way many are white).
#
# So, don't fall in their trap of making our countries defence a war between races which will end quite bad for all of us.
#
# Let's unite against their movement.
#
# When you take the gloves off make sure every blow is directed to the right person.
#
# Don't be part of the problem, dont let the thirst of vengeance to blind you.
#
# All the best. God bless you and guide you.,
#
# 182: ->  Jajaja increíble que contrataron al mismo doblador de las pelis de la roca xdd,
#
# 183: ->  Revisiting this video 7 years later, still has me amazed!,
#
# 184: ->  I'm 5ft imagine if i bought a used Mclaren F1 that some 6ft 6 dude had crafted for him,
#
# 185: ->  I could listen to Neil for days straight,
#
# 186: ->  Customer:"So how much is this going to cost?"Rolls-Royce:"Yes."Customer:"Sold.",
#
# 187: ->  The stars should be what the sky is over the car at any given moment.,
#
# 188: ->  中國之所以強大，是因為中國共產黨將十四億中國人的幸福，作為奮鬥的目標🇨🇳🇨🇳感恩中國共產黨,
#
# 189: ->  Go out there and help the elephant.,
#
# 190: ->  The averaging out the inputs of 2 controllers just seemed always like a flaw to me. Dunno why the captains seat just doesn't have a built in take over if theres large discrepencies when hes hired to be in command anyways and just have a backup selector to switch with instead incase of issues. Having 2 people able to input controls just seems a recipe for confusion and disaster.,
#
# 191: ->  I have sort of a bird phobia. I’m only chill around Parrotsand the birds at PetSmart and owls that are properly trained and all that. I’m also not afraid of Macaws nor Chickens/Roosters. That’s it. I’m afraid of every other bird for the most part (idk why though).,
#
# 192: ->  It's disturbing that the tray table is something that Airbus pilots would actually brag about... not only does it not improve aircraft control or safety, I would argue it makes both worse. We're talking about a commercial aircraft cockpit, not a lounge chair.
# Force-feedback sticks don't fix what seems to me to be one of the most basic problems inherent in side sticks, which is that the pilot and copilot have to use different hands. The muscle memory developed as a first officer in the right seat becomes almost useless the moment that pilot switches to the left side... it has to be completely relearned. Amplified by most pilots being right-handed and now having to rely on their off-hands. It almost seems as if Airbus pilots have become so reliant on autopilot systems that a lack of fine motor control on the stick isn't something that they even care about.,
#
# 193: ->  9:12Speaking of toppings: Have you ever tried fries on a pizza?!
# Thank me later.,
#
# 194: ->  i love you papua indonesia,
#
# 195: ->  Dear John, your humorous little anecdote about 'Is there a gender wage gap in child labor?' on the cover of that fictitious magazine is perhaps problematic because several US states are currently seeking to either amend or remove child labour provisions.  Perhaps that could be a subject for one of your future diatribes? Don't get me wrong. I find your diatribes highly informative, entertaining and thought provoking. Even factual, which is more than can be said for a lot of US media outlets these days.  Keep it up John! [HUH!   Well, whaddya know... my first Dear John letter....],
#
# 196: ->  #lifetimesupportofficial,
#
# 197: ->  It's ugly asf though,
#
# 198: ->  Nothing wrong with old Jim bean,
#
# 199: ->  take a fresh ice cream machine, / mixer,, coated cone,
